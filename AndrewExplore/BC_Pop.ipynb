# %%
import numpy as np
import pandas as pd

# %%
BCPop1 = pd.read_excel("./BC/Cleaning/pop_municipal_subprovincial_areas_pop_2001_2011.xlsx", header=2)
BCPop2 = pd.read_excel("./BC/Cleaning/pop_municipial_subprov_areas.xlsx", header=2)

# %%
BCPop1.sample(5)
# Out:
#          SGC               Name Area Type     2001     2002     2003     2004  \
# 209  49022.0           Hazelton        VL    360.0    343.0    331.0    313.0
# 107  23000.0  Alberni-Clayoquot        RD  31608.0  31251.0  31279.0  31281.0
# 108  23008.0       Port Alberni        CY  18476.0  18182.0  18106.0  18037.0
# 237  55025.0      Hudson's Hope        DM   1074.0   1066.0   1059.0   1048.0
# 13    3004.0            Creston         T   4958.0   4914.0   4892.0   4891.0
#
#         2005     2006     2007     2008     2009     2010     2011
# 209    303.0    301.0    300.0    303.0    304.0    303.0    305.0
# 107  31522.0  31479.0  31430.0  31562.0  31699.0  31749.0  31623.0
# 108  18085.0  17985.0  18028.0  18036.0  18121.0  18149.0  18026.0
# 237   1041.0   1036.0   1033.0   1016.0    993.0    945.0    994.0
# 13    4899.0   4905.0   4957.0   5164.0   5235.0   5404.0   5352.0

# %%
BCPop2.head()
# Out:
#      SGC                       Name Area Type     2011     2012     2013  \
# 0  23000          Alberni-Clayoquot        RD  31623.0  31444.0  31335.0
# 1  23008               Port Alberni        CY  18026.0  17928.0  17766.0
# 2  23025                     Tofino        DM   1952.0   1977.0   1981.0
# 3  23019                   Ucluelet        DM   1676.0   1645.0   1701.0
# 4  23999       Unincorporated Areas       RDR   9969.0   9894.0   9887.0
#
#       2014     2015     2016     2017  ...  2012-13 Changes  2013-14 Changes  \
# 0  31503.0  31743.0  32287.0  32579.0  ...           -0.003            0.005
# 1  17753.0  18012.0  18360.0  18466.0  ...           -0.009           -0.001
# 2   2050.0   2068.0   2082.0   2188.0  ...            0.002            0.035
# 3   1653.0   1706.0   1812.0   1897.0  ...            0.034           -0.028
# 4  10047.0   9957.0  10033.0  10028.0  ...           -0.001            0.016
#
# ...

# %%
BCPop1[BCPop1['Area Type']=='RD']
# Out:
#          SGC                  Name Area Type       2001       2002       2003  \
# 1     1000.0         East Kootenay        RD    58584.0    58041.0    57605.0
# 12    3000.0      Central Kootenay        RD    59366.0    58427.0    57802.0
# 24    5000.0     Kootenay-Boundary        RD    33126.0    32427.0    31930.0
# 35    7000.0  Okanagan-Similkameen        RD    79919.0    80189.0    80474.0
# 44    9000.0         Fraser Valley        RD   247745.0   250410.0   253771.0
# 53   15000.0     Greater Vancouver        RD  2074885.0  2099303.0  2116536.0
# 77   17000.0               Capital        RD   340002.0   342012.0   344180.0
# 93   19000.0       Cowichan Valley        RD    75040.0    75316.0    76162.0
# 100  21000.0               Nanaimo        RD   132480.0   134102.0   136127.0
# 107  23000.0     Alberni-Clayoquot        RD    31608.0    31251.0    31279.0
# 113  24000.0            Strathcona        RD    42622.0    42230.0    42228.0
# ...

# %%
BCPop2[BCPop2['Area Type']=='RD']
# Out:
#        SGC                    Name Area Type       2011       2012       2013  \
# 0    23000       Alberni-Clayoquot        RD    31623.0    31444.0    31335.0
# 6    51000         Bulkley-Nechako        RD    39917.0    39768.0    39660.0
# 17   17000                 Capital        RD   367617.0   374298.0   380835.0
# 33   41000                 Cariboo        RD    63380.0    63243.0    63280.0
# 40   45000           Central Coast        RD     3285.0     3306.0     3373.0
# 42    3000        Central Kootenay        RD    59348.0    59217.0    59495.0
# 54   35000        Central Okanagan        RD   183607.0   186128.0   189123.0
# 61   39000        Columbia-Shuswap        RD    51275.0    51069.0    51299.0
# 68   26000            Comox Valley        RD    64486.0    65062.0    65336.0
# 74   19000         Cowichan Valley        RD    81567.0    81897.0    82588.0
# 81    1000           East Kootenay        RD    57743.0    58613.0    59540.0
# ...

# %%
# apparently pandas doesn't like comparing boolean values like this
(BCPop1['Area Type'] == 'RD') or (BCPop1['Area Type'] == 'R')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_8/jjh50gt94jn4k4npz9dw05v40000gn/T/ipykernel_63106/2955672646.py in ?()
#       1 # apparently pandas doesn't like comparing boolean values like this
# ----> 2 (BCPop1['Area Type'] == 'RD') or (BCPop1['Area Type'] == 'R')
#
# /opt/homebrew/Caskroom/miniforge/base/envs/firstenvironment/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# trying to add in the one with missing 'Area Type', but lots of rows have this!
len( BCPop1.loc[BCPop1['Area Type'].isin(['RD','R',np.nan])] )
# Out:
# 74

# %%
# found an extra space in the name
BCPop1[BCPop1['Name'] == 'North Coast ']
# Out:
#          SGC          Name Area Type     2001     2002     2003     2004  \
# 198  47000.0  North Coast        NaN  22540.0  21926.0  21358.0  20908.0
#
#         2005     2006     2007     2008     2009     2010     2011
# 198  20498.0  20170.0  19962.0  19880.0  19670.0  19460.0  19133.0

# %%
BCPop1.iloc[198]['Area Type']
# Out:
# nan

# %%
# North Coast has a missing Area Type attribute, try to add that; 
# this fails because many rows have missing Area Type
len(BCPop1.loc[ (BCPop1['Area Type'].isin(['RD','R'])) or (BCPop1['Name'] == 'North Coast ') ])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/_8/jjh50gt94jn4k4npz9dw05v40000gn/T/ipykernel_63106/940604377.py in ?()
#       1 # North Coast has a missing Area Type attribute, try to add that;
#       2 # this fails because many rows have missing Area Type
# ----> 3 len(BCPop1.loc[ (BCPop1['Area Type'].isin(['RD','R'])) or (BCPop1['Name'] == 'North Coast ') ])
#
# /opt/homebrew/Caskroom/miniforge/base/envs/firstenvironment/lib/python3.11/site-packages/pandas/core/generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ...

# %%
# try to add North Coast using its nonzero SGC
regional1 = BCPop1.loc[BCPop1['Area Type'].isin(['RD','R',np.nan]) & (BCPop1['SGC'] >0) ].copy()
print(len(regional1))
regional2 = BCPop2.loc[BCPop2['Area Type'].isin(['RD','R'])].copy()
print(len(regional2))
# Out:
# 29
# 29

# %%
# possibly want rows labelled by years(/months)
regional1.transpose()
# Out:
#                      1                 12                 24   \
# SGC               1000.0            3000.0             5000.0
# Name       East Kootenay  Central Kootenay  Kootenay-Boundary
# Area Type             RD                RD                 RD
# 2001             58584.0           59366.0            33126.0
# 2002             58041.0           58427.0            32427.0
# 2003             57605.0           57802.0            31930.0
# 2004             57125.0           57518.0            31424.0
# 2005             56919.0           57345.0            31423.0
# 2006             56902.0           57204.0            31428.0
# 2007             57444.0           57739.0            31608.0
# 2008             58060.0           58436.0            31721.0
# 2009             58276.0           58838.0            31712.0
# 2010             58151.0           59244.0            31727.0
# 2011             57743.0           59348.0            31530.0
#
# ...

# %%
R1 = regional1.drop(columns=['SGC','Area Type']).sort_values(by='Name').transpose()
R1
# Out:
#                     107              214       77       182            196  \
# Name  Alberni-Clayoquot  Bulkley-Nechako   Capital  Cariboo  Central Coast
# 2001            31608.0          42493.0  340002.0  68226.0         3918.0
# 2002            31251.0          41456.0  342012.0  66701.0         3787.0
# 2003            31279.0          40837.0  344180.0  65487.0         3538.0
# 2004            31281.0          40542.0  346761.0  64573.0         3468.0
# 2005            31522.0          39796.0  352078.0  64005.0         3377.0
# 2006            31479.0          39378.0  355050.0  63872.0         3273.0
# 2007            31430.0          39531.0  357049.0  64294.0         3256.0
# 2008            31562.0          39739.0  359585.0  64679.0         3241.0
# 2009            31699.0          39721.0  363445.0  64169.0         3242.0
# 2010            31749.0          39979.0  366716.0  63796.0         3261.0
# ...

# %%
R2 = regional2.drop(columns=['SGC','Area Type']).iloc[:,:-12].sort_values(by='Name').transpose()
R2
# Out:
#                     0                6         17       33             40   \
# Name  Alberni-Clayoquot  Bulkley-Nechako   Capital  Cariboo  Central Coast
# 2011            31623.0          39917.0  367617.0  63380.0         3285.0
# 2012            31444.0          39768.0  374298.0  63243.0         3306.0
# 2013            31335.0          39660.0  380835.0  63280.0         3373.0
# 2014            31503.0          39663.0  386307.0  63624.0         3360.0
# 2015            31743.0          39381.0  392200.0  63858.0         3359.0
# 2016            32287.0          39474.0  400562.0  64293.0         3464.0
# 2017            32579.0          39458.0  406681.0  64710.0         3485.0
# 2018            32978.0          39496.0  413016.0  65146.0         3548.0
# 2019            33516.0          39586.0  419827.0  65381.0         3553.0
# 2020            33856.0          39527.0  425818.0  65381.0         3578.0
# ...

# %%
R1.columns = R1.iloc[0]
R1
# Out:
# Name  Alberni-Clayoquot  Bulkley-Nechako   Capital  Cariboo  Central Coast  \
# Name  Alberni-Clayoquot  Bulkley-Nechako   Capital  Cariboo  Central Coast
# 2001            31608.0          42493.0  340002.0  68226.0         3918.0
# 2002            31251.0          41456.0  342012.0  66701.0         3787.0
# 2003            31279.0          40837.0  344180.0  65487.0         3538.0
# 2004            31281.0          40542.0  346761.0  64573.0         3468.0
# 2005            31522.0          39796.0  352078.0  64005.0         3377.0
# 2006            31479.0          39378.0  355050.0  63872.0         3273.0
# 2007            31430.0          39531.0  357049.0  64294.0         3256.0
# 2008            31562.0          39739.0  359585.0  64679.0         3241.0
# 2009            31699.0          39721.0  363445.0  64169.0         3242.0
# 2010            31749.0          39979.0  366716.0  63796.0         3261.0
# ...

# %%
R1 = R1.drop('Name')
R1
# Out:
# Name Alberni-Clayoquot Bulkley-Nechako   Capital  Cariboo Central Coast  \
# 2001           31608.0         42493.0  340002.0  68226.0        3918.0
# 2002           31251.0         41456.0  342012.0  66701.0        3787.0
# 2003           31279.0         40837.0  344180.0  65487.0        3538.0
# 2004           31281.0         40542.0  346761.0  64573.0        3468.0
# 2005           31522.0         39796.0  352078.0  64005.0        3377.0
# 2006           31479.0         39378.0  355050.0  63872.0        3273.0
# 2007           31430.0         39531.0  357049.0  64294.0        3256.0
# 2008           31562.0         39739.0  359585.0  64679.0        3241.0
# 2009           31699.0         39721.0  363445.0  64169.0        3242.0
# 2010           31749.0         39979.0  366716.0  63796.0        3261.0
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
#
# Name Central Kootenay Central Okanagan Columbia-Shuswap    Comox  \
# ...

# %%
R2.columns = R2.iloc[0]
R2
# Out:
# Name  Alberni-Clayoquot  Bulkley-Nechako   Capital  Cariboo  Central Coast  \
# Name  Alberni-Clayoquot  Bulkley-Nechako   Capital  Cariboo  Central Coast
# 2011            31623.0          39917.0  367617.0  63380.0         3285.0
# 2012            31444.0          39768.0  374298.0  63243.0         3306.0
# 2013            31335.0          39660.0  380835.0  63280.0         3373.0
# 2014            31503.0          39663.0  386307.0  63624.0         3360.0
# 2015            31743.0          39381.0  392200.0  63858.0         3359.0
# 2016            32287.0          39474.0  400562.0  64293.0         3464.0
# 2017            32579.0          39458.0  406681.0  64710.0         3485.0
# 2018            32978.0          39496.0  413016.0  65146.0         3548.0
# 2019            33516.0          39586.0  419827.0  65381.0         3553.0
# 2020            33856.0          39527.0  425818.0  65381.0         3578.0
# ...

# %%
R2 = R2.drop('Name')

# %%
R1
# Out:
# Name Alberni-Clayoquot Bulkley-Nechako   Capital  Cariboo Central Coast  \
# 2001           31608.0         42493.0  340002.0  68226.0        3918.0
# 2002           31251.0         41456.0  342012.0  66701.0        3787.0
# 2003           31279.0         40837.0  344180.0  65487.0        3538.0
# 2004           31281.0         40542.0  346761.0  64573.0        3468.0
# 2005           31522.0         39796.0  352078.0  64005.0        3377.0
# 2006           31479.0         39378.0  355050.0  63872.0        3273.0
# 2007           31430.0         39531.0  357049.0  64294.0        3256.0
# 2008           31562.0         39739.0  359585.0  64679.0        3241.0
# 2009           31699.0         39721.0  363445.0  64169.0        3242.0
# 2010           31749.0         39979.0  366716.0  63796.0        3261.0
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
#
# Name Central Kootenay Central Okanagan Columbia-Shuswap    Comox  \
# ...

# %%
R2
# Out:
# Name Alberni-Clayoquot Bulkley-Nechako   Capital  Cariboo Central Coast  \
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
# 2012           31444.0         39768.0  374298.0  63243.0        3306.0
# 2013           31335.0         39660.0  380835.0  63280.0        3373.0
# 2014           31503.0         39663.0  386307.0  63624.0        3360.0
# 2015           31743.0         39381.0  392200.0  63858.0        3359.0
# 2016           32287.0         39474.0  400562.0  64293.0        3464.0
# 2017           32579.0         39458.0  406681.0  64710.0        3485.0
# 2018           32978.0         39496.0  413016.0  65146.0        3548.0
# 2019           33516.0         39586.0  419827.0  65381.0        3553.0
# 2020           33856.0         39527.0  425818.0  65381.0        3578.0
# 2021           34322.0         39927.0  430484.0  65624.0        3621.0
# 2022           34867.0         40201.0  439950.0  65855.0        3688.0
#
# ...

# %%
print(R1.columns)
print()
print(R2.columns)
# Out:
# Index(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Coast', 'Central Kootenay', 'Central Okanagan',
#        'Columbia-Shuswap', 'Comox', 'Cowichan Valley', 'East Kootenay',
#        'Fraser Valley', 'Fraser-Fort George', 'Greater Vancouver',
#        'Kitimat-Stikine', 'Kootenay-Boundary', 'Mount Waddington', 'Nanaimo',
#        'North Coast ', 'North Okanagan', 'Northern Rockies',
#        'Okanagan-Similkameen', 'Peace River', 'Powell River',
#        'Squamish-Lillooet', 'Stikine', 'Strathcona', 'Sunshine Coast',
#        'Thompson-Nicola'],
#       dtype='object', name='Name')
#
# Index(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Coast', 'Central Kootenay', 'Central Okanagan',
#        'Columbia-Shuswap', 'Comox Valley', 'Cowichan Valley', 'East Kootenay',
#        'Fraser Valley', 'Fraser-Fort George', 'Greater Vancouver',
#        'Kitimat-Stikine', 'Kootenay Boundary', 'Mount Waddington', 'Nanaimo',
# ...

# %%
R1 = R1.rename(columns={'Comox':'Comox Valley', 'North Coast ':'North Coast', 'Kootenay-Boundary':'Kootenay Boundary'})

# %%
R1.columns
# Out:
# Index(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Coast', 'Central Kootenay', 'Central Okanagan',
#        'Columbia-Shuswap', 'Comox Valley', 'Cowichan Valley', 'East Kootenay',
#        'Fraser Valley', 'Fraser-Fort George', 'Greater Vancouver',
#        'Kitimat-Stikine', 'Kootenay Boundary', 'Mount Waddington', 'Nanaimo',
#        'North Coast', 'North Okanagan', 'Northern Rockies',
#        'Okanagan-Similkameen', 'Peace River', 'Powell River',
#        'Squamish-Lillooet', 'Stikine', 'Strathcona', 'Sunshine Coast',
#        'Thompson-Nicola'],
#       dtype='object', name='Name')

# %%
R2 = R2.rename(columns={'Skeena-Queen Charlotte':'North Coast'})

# %%
R2 = R2.transpose().sort_values(by='Name').transpose()

# %%
R2.columns
# Out:
# Index(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Coast', 'Central Kootenay', 'Central Okanagan',
#        'Columbia-Shuswap', 'Comox Valley', 'Cowichan Valley', 'East Kootenay',
#        'Fraser Valley', 'Fraser-Fort George', 'Greater Vancouver',
#        'Kitimat-Stikine', 'Kootenay Boundary', 'Mount Waddington', 'Nanaimo',
#        'North Coast', 'North Okanagan', 'Northern Rockies',
#        'Okanagan-Similkameen', 'Peace River', 'Powell River',
#        'Squamish-Lillooet', 'Stikine', 'Strathcona', 'Sunshine Coast',
#        'Thompson-Nicola'],
#       dtype='object', name='Name')

# %%
len(pd.concat([R1,R2]).transpose())
# Out:
# 29

# %%
BCRegPop1 = pd.concat([R1,R2])

# %% [markdown]
# Here we finally have a table with populations for years 2001-2022 for all regional districts in BC (along with 2 other "regions").  This may be enough for some applications, because other variables do not have data prior to 2000.

# %%
BCRegPop1
# Out:
# Name Alberni-Clayoquot Bulkley-Nechako   Capital  Cariboo Central Coast  \
# 2001           31608.0         42493.0  340002.0  68226.0        3918.0
# 2002           31251.0         41456.0  342012.0  66701.0        3787.0
# 2003           31279.0         40837.0  344180.0  65487.0        3538.0
# 2004           31281.0         40542.0  346761.0  64573.0        3468.0
# 2005           31522.0         39796.0  352078.0  64005.0        3377.0
# 2006           31479.0         39378.0  355050.0  63872.0        3273.0
# 2007           31430.0         39531.0  357049.0  64294.0        3256.0
# 2008           31562.0         39739.0  359585.0  64679.0        3241.0
# 2009           31699.0         39721.0  363445.0  64169.0        3242.0
# 2010           31749.0         39979.0  366716.0  63796.0        3261.0
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
# ...

# %% [markdown]
# We can start working on the pre-2001 population data.  This might not be necessary.  The main problem is that this data is broken down by municipalities, and the regional districts they belong to are not given.

# %%
BCPop0 = pd.read_excel("./BC/Cleaning/municipal_census_pop_1921_2011.xlsx", header=1)

# %%
BCPop0
# Out:
#                                             Unnamed: 0 Unnamed: 1   1921  \
# 0                                       100 Mile House        NaN   --
# 1                                           Abbotsford        NaN   --
# 2                                           Aennofield        [1]   --
# 3                                              Alberni        [2]    540
# 4                                            Alert Bay        NaN   --
# ..                                                 ...        ...    ...
# 194  [8] Dissolved with part annexed to Kelowna, an...        NaN    NaN
# 195                       [9] Amalgamated with Kelowna        NaN    NaN
# 196                                                NaN        NaN    NaN
# 197  Source: Statistics Canada, Prepared by BC Stat...        NaN    NaN
# 198  1941, 1951, 1956, 1961, 1966, 1971, 1976, 1981...        NaN    NaN
#
#       1931   1941                                    1951   1956   1961  1966  \
# ...

# %%
BCPop0.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1',         1921,         1931,         1941,
#                1951,         1956,         1961,         1966,         1971,
#                1976,         1981,         1986,         1991,         1996,
#                2001,         2006,         2011],
#       dtype='object')

# %%
BCPop0 = BCPop0.rename(columns={'Unnamed: 0':'Name', 'Unnamed: 1':'RD'})

# %%
BCPop0.loc[0,'RD'] = 'Cariboo'

# %%
BCPop0.loc[1,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[2,'RD'] = 'Peace River'

# %%
BCPop0.loc[3,'RD'] = 'Alberni-Clayoquot'

# %%
BCPop0.loc[4,'RD'] = 'Mount Waddington'

# %%
BCPop0.loc[5,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[6,'RD'] = 'North Okanagan'

# %%
BCPop0.loc[7,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[8,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[9,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[10,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[11,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[12,'RD'] = 'Bulkley-Nechako'

# %%
BCPop0.loc[13,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[14,'RD'] = 'Strathcona'

# %%
BCPop0.loc[15,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[16,'RD'] = 'Central Kootenay'

# %%
BCPop0.loc[17,'RD'] = 'Capital'

# %%
BCPop0.loc[18,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[19,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.iloc[10:20]
# Out:
#                Name                 RD   1921   1931   1941   1951   1956  \
# 10     Bowen Island  Greater Vancouver    NaN    NaN    NaN    NaN    NaN
# 11          Burnaby  Greater Vancouver  12883  25564  30328  58376  83745
# 12       Burns Lake    Bulkley-Nechako   --      202    218    801   1016
# 13      Cache Creek    Thompson-Nicola   --     --     --     --     --
# 14   Campbell River         Strathcona   --     --     --     1986   3069
# 15      Canal Flats      East Kootenay   --     --     --     --     --
# 16        Castlegar   Central Kootenay   --     --     --     1329   1705
# 17  Central Saanich            Capital   --     --     --     2069   2477
# 18     Chapman Camp      East Kootenay   --     --      513    588    567
# 19            Chase    Thompson-Nicola   --     --     --     --     --
#
#       1961    1966    1971    1976    1981    1986    1991    1996    2001  \
# 10    --      --      --      --      --      --      --      --      2957
# ...

# %%
BCPop0.iloc[20:30]
# Out:
#            Name                 RD   1921   1931   1941   1951   1956   1961  \
# 20     Chetwynd        Peace River   --     --     --     --     --     --
# 21   Chilliwack      Fraser Valley   1767   2461   3675   5663   7297   8259
# 22  Chilliwhack      Fraser Valley   3161   5802   7787  13677  16350  18296
# 23   Clearwater    Thompson-Nicola   --     --     --     --     --     --
# 24      Clinton    Thompson-Nicola   --     --     --     --     --     --
# 25   Coldstream     North Okanagan    711    867    867   1402   1613   2161
# 26      Colwood            Capital   --     --     --     --     --     --
# 27        Comox       Comox Valley   --     --     --      714   1151   1756
# 28    Coquitlam  Greater Vancouver   2374   4871   7949  15697  20800  29053
# 29    Courtenay       Comox Valley    810   1219   1737   2553   3025   3485
#
#      1966   1971   1976   1981   1986   1991    1996    2001    2006    2011
# ...

# %%
BCPop0.loc[20,'RD'] = 'Peace River'

# %%
BCPop0.loc[21,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[22,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[23,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[24,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[25,'RD'] = 'North Okanagan'

# %%
BCPop0.loc[26,'RD'] = 'Capital'

# %%
BCPop0.loc[27,'RD'] = 'Comox Valley'

# %%
BCPop0.loc[28,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[29,'RD'] = 'Comox Valley'

# %%
BCPop0.iloc[30:40]
# Out:
#               Name                 RD   1921   1931   1941   1951   1956  \
# 30  Cranberry Lake       Powell River   --     --     --     1350   --
# 31       Cranbrook      East Kootenay   2725   3067   2568   3621   4562
# 32         Creston   Central Kootenay   --      695   1153   1626   1844
# 33      Cumberland       Comox Valley   1179    907    885    971   1039
# 34    Dawson Creek        Peace River   --     --      518   3589   7531
# 35           Delta  Greater Vancouver   2839   3709   4287   6701   8752
# 36        Dufferin    Thompson-Nicola   --     --     --     --     --
# 37          Duncan    Cowichan Valley   1178   1843   2189   2784   3247
# 38         Elkford      East Kootenay    NaN    NaN    NaN    NaN    NaN
# 39         Enderby     North Okanagan    783    555    538    877    965
#
#      1961   1966   1971   1976   1981   1986   1991   1996   2001   2006  \
# 30   --     --     --     --     --     --     --     --     --     --
# ...

# %%
BCPop0.loc[30,'RD'] = 'Powell River'

# %%
BCPop0.loc[31,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[32,'RD'] = 'Central Kootenay'

# %%
BCPop0.loc[33,'RD'] = 'Comox Valley'

# %%
BCPop0.loc[34,'RD'] = 'Peace River'

# %%
BCPop0.loc[35,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[36,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[37,'RD'] = 'Cowichan Valley'

# %%
BCPop0.loc[38,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[39,'RD'] = 'North Okanagan'

# %%
BCPop0.iloc[40:50]
# Out:
#               Name                 RD   1921   1931   1941   1951   1956  \
# 40       Esquimalt            Capital   3458   3274   3737  10153  10384
# 41          Fernie      East Kootenay   2802   2732   2545   2551   2808
# 42     Fort Nelson   Northern Rockies   --     --     --     --     --
# 43  Fort St. James    Bulkley-Nechako   --     --     --     --      615
# 44   Fort St. John        Peace River   --     --     --      884   1908
# 45     Fraser Lake    Bulkley-Nechako   --     --     --     --     --
# 46    Fraser Mills  Greater Vancouver    600    616    552    369    216
# 47       Fruitvale  Kootenay Boundary   --     --     --     --      870
# 48         Gibsons     Sunshine Coast   --      131    262    722    990
# 49        Glenmore   Central Okanagan    263    303    404   1119   1287
#
#      1961   1966   1971   1976   1981   1986   1991   1996   2001   2006  \
# 40  12048  12891  12922  15053  15870  15972  16192  16151  16127  16840
# ...

# %%
BCPop0.loc[40,'RD'] = 'Capital'

# %%
BCPop0.loc[41,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[42,'RD'] = 'Northern Rockies'

# %%
BCPop0.loc[43,'RD'] = 'Bulkley-Nechako'

# %%
BCPop0.loc[44,'RD'] = 'Peace River'

# %%
BCPop0.loc[45,'RD'] = 'Bulkley-Nechako'

# %%
BCPop0.loc[46,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[47,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.loc[48,'RD'] = 'Sunshine Coast'

# %%
BCPop0.loc[49,'RD'] = 'Central Okanagan'

# %%
BCPop0.iloc[50:60]
# Out:
#                     Name                 RD   1921   1931   1941   1951  \
# 50            Gold River         Strathcona   --     --     --     --
# 51                Golden   Columbia-Shuswap   --     --     --     --
# 52           Grand Forks  Kootenay Boundary   1469   1298   1259   1646
# 53              Granisle    Bulkley-Nechako   --     --     --     --
# 54             Greenwood  Kootenay Boundary    371    171    363    809
# 55             Guisachan   Central Okanagan   --     --     --     --
# 56  Harrison Hot Springs      Fraser Valley   --     --     --      477
# 57              Hazelton    Kitimat-Stikine   --     --     --     --
# 58             Highlands            Capital   --     --     --     --
# 59                  Hope      Fraser Valley   --      374    515   1668
#
#      1956   1961   1966   1971   1976   1981   1986   1991   1996   2001  \
# 50   --     --      598   1896   1942   2225   1879   2166   2041   1359
# ...

# %%
BCPop0.loc[50,'RD'] = 'Strathcona'

# %%
BCPop0.loc[51,'RD'] = 'Columbia-Shuswap'

# %%
BCPop0.loc[52,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.loc[53,'RD'] = 'Bulkley-Nechako'

# %%
BCPop0.loc[54,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.loc[55,'RD'] = 'Central Okanagan'

# %%
BCPop0.loc[56,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[57,'RD'] = 'Kitimat-Stikine'

# %%
BCPop0.loc[58,'RD'] = 'Capital'

# %%
BCPop0.loc[59,'RD'] = 'Fraser Valley'

# %%
BCPop0.iloc[60:70]
# Out:
#              Name                    RD   1921   1931   1941   1951   1956  \
# 60        Houston       Bulkley-Nechako   --     --     --     --     --
# 61  Hudson's Hope           Peace River   --     --     --     --     --
# 62      Invermere         East Kootenay   --     --     --      418    543
# 63       Kamloops       Thompson-Nicola   4501   6167   5959   8099   9096
# 64          Kaslo      Central Kootenay    950    523    468    730    669
# 65        Kelowna      Central Okanagan   2520   4655   5118   8517   9181
# 66           Kent         Fraser Valley   1054   1207   1287   1725   1989
# 67       Keremeos  Okanagan-Similkameen   --     --     --     --     --
# 68      Kimberley         East Kootenay   --     --     --     5933   5774
# 69       Kinnaird      Central Kootenay   --     --     --      947   1305
#
#      1961   1966   1971   1976   1981   1986   1991   1996   2001    2006  \
# ...

# %%
BCPop0.loc[60,'RD'] = 'Bulkley-Nechako'

# %%
BCPop0.loc[61,'RD'] = 'Peace River'

# %%
BCPop0.loc[62,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[63,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[64,'RD'] = 'Central Kootenay'

# %%
BCPop0.loc[65,'RD'] = 'Central Okanagan'

# %%
BCPop0.loc[66,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[67,'RD'] = 'Okanagan-Similkameen'

# %%
BCPop0.loc[68,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[69,'RD'] = 'Central Kootenay'

# %%
BCPop0.iloc[70:80]
# Out:
#              Name                 RD   1921   1931   1941   1951   1956  \
# 70        Kitimat    Kitimat-Stikine   --     --     --     --     9676
# 71      Ladysmith    Cowichan Valley   1967   1443   1706   2094   2107
# 72   Lake Country   Central Okanagan   --     --     --     --     --
# 73  Lake Cowichan    Cowichan Valley   --     --     --     1628   1949
# 74       Langford            Capital   --     --     --     --     --
# 75      Langley C  Greater Vancouver   --     --     --     --     2131
# 76     Langley DM  Greater Vancouver   4881   5537   7769  12267  12441
# 77     Lantzville            Nanaimo   --     --     --     --     --
# 78       Lillooet  Squamish-Lillooet   --     --     --      469   1083
# 79      Lions Bay  Greater Vancouver   --     --     --     --     --
#
#      1961   1966   1971   1976   1981   1986   1991   1996   2001   2006  \
# 70   8217   9792  11803  11956  12814  11196  11305  11136  10285   8987
# ...

# %%
BCPop0.loc[70,'RD'] = 'Kitimat-Stikine'

# %%
BCPop0.loc[71,'RD'] = 'Cowichan Valley'

# %%
BCPop0.loc[72,'RD'] = 'Central Okanagan'

# %%
BCPop0.loc[73,'RD'] = 'Cowichan Valley'

# %%
BCPop0.loc[74,'RD'] = 'Capital'

# %%
BCPop0.loc[75,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[76,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[77,'RD'] = 'Nanaimo'

# %%
BCPop0.loc[78,'RD'] = 'Squamish-Lillooet'

# %%
BCPop0.loc[79,'RD'] = 'Greater Vancouver'

# %%
BCPop0.iloc[80:90]
# Out:
#            Name                  RD   1921   1931   1941   1951   1956   1961  \
# 80   Logan Lake     Thompson-Nicola   --     --     --     --     --     --
# 81        Lumby      North Okanagan   --     --     --     --      786    842
# 82       Lytton     Thompson-Nicola   --     --     --      312    329    442
# 83    Mackenzie  Fraser-Fort George   --     --     --     --     --     --
# 84  Maple Ridge   Greater Vancouver   3772   4932   6476   9891  12502  16748
# 85   Marysville       East Kootenay   --     --     --      807    930   1057
# 86       Masset         North Coast   --     --     --     --     --      547
# 87      Matsqui       Fraser Valley   3763   3835   5601  10308  11521  14293
# 88      McBride  Fraser-Fort George   --     --      237    489    582    590
# 89      Merritt     Thompson-Nicola   1389   1296    940   1251   1790   3039
#
#      1966   1971   1976   1981   1986   1991   1996   2001   2006   2011
# ...

# %%
BCPop0.loc[80,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[81,'RD'] = 'North Okanagan'

# %%
BCPop0.loc[82,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[83,'RD'] = 'Fraser-Fort George'

# %%
BCPop0.loc[84,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[85,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[86,'RD'] = 'North Coast'

# %%
BCPop0.loc[87,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[88,'RD'] = 'Fraser-Fort George'

# %%
BCPop0.loc[89,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.iloc[90:100]
# Out:
#             Name                 RD   1921   1931   1941   1951   1956   1961  \
# 90     Metchosin            Capital   --     --     --     --     --     --
# 91        Midway  Kootenay Boundary   --     --     --     --     --     --
# 92       Mission      Fraser Valley   3025   2279   2718   4467   4711   5324
# 93  Mission City      Fraser Valley   --     1314   1957   2668   3010   3251
# 94      Montrose  Kootenay Boundary   --     --     --     --     --      862
# 95        Nakusp   Central Kootenay   --     --     --     --     --     --
# 96       Nanaimo            Nanaimo   6304   6745   6635   7196  12705  14135
# 97         Natal      East Kootenay   --     --     --     --     --      829
# 98        Nelson   Central Kootenay   5230   5992   5912   6772   7226   7074
# 99    New Denver   Central Kootenay   --      306    310    771    736    564
#
#      1966   1971   1976   1981   1986   1991   1996   2001   2006   2011
# ...

# %%
BCPop0.loc[90,'RD'] = 'Capital'

# %%
BCPop0.loc[91,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.loc[92,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[93,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[94,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.loc[95,'RD'] = 'Central Kootenay'

# %%
BCPop0.loc[96,'RD'] = 'Nanaimo'

# %%
BCPop0.loc[97,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[98,'RD'] = 'Central Kootenay'

# %%
BCPop0.loc[99,'RD'] = 'Central Kootenay'

# %%
BCPop0.iloc[100:110]
# Out:
#                    Name                    RD   1921   1931   1941   1951  \
# 100        New Hazelton       Kitimat-Stikine   --     --     --     --
# 101     New Westminster     Greater Vancouver  14495  17524  21967  28639
# 102      North Cowichan       Cowichan Valley   2664   3291   4590   6665
# 103      North Kamloops       Thompson-Nicola   --     --     --     1979
# 104       North Saanich               Capital   --     --     --     --
# 105   North Vancouver C     Greater Vancouver   7652   8510   8914  15687
# 106  North Vancouver DM     Greater Vancouver   2950   4788   5931  14469
# 107    Northern Rockies      Northern Rockies   --     --     --     --
# 108             Oak Bay               Capital   4159   5892   9240  11960
# 109              Oliver  Okanagan-Similkameen   --     --     --     1000
#
#       1956   1961   1966   1971   1976   1981   1986   1991   1996   2001  \
# 100   --     --     --     --     --      712    796    786    822    750
# ...

# %%
BCPop0.loc[100,'RD'] = 'Kitimat-Stikine'

# %%
BCPop0.loc[101,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[102,'RD'] = 'Cowichan Valley'

# %%
BCPop0.loc[103,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[104,'RD'] = 'Capital'

# %%
BCPop0.loc[105,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[106,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[107,'RD'] = 'Northern Rockies'

# %%
BCPop0.loc[108,'RD'] = 'Capital'

# %%
BCPop0.loc[109,'RD'] = 'Okanagan-Similkameen'

# %%
BCPop0.iloc[110:120]
# Out:
#               Name                    RD   1921   1931   1941   1951   1956  \
# 110        Osoyoos  Okanagan-Similkameen   --     --     --      899    860
# 111     Parksville               Nanaimo   --     --     --      882   1112
# 112      Peachland      Central Okanagan    466    318    479    614    705
# 113      Pemberton     Squamish-Lillooet   --     --     --     --     --
# 114      Penticton  Okanagan-Similkameen   3979   4640   5777  10548  11894
# 115   Pitt Meadows     Greater Vancouver    595    832   1119   1434   1652
# 116     Point Grey     Greater Vancouver  13736   --     --     --     --
# 117   Port Alberni     Alberni-Clayoquot   1056   2356   4584   7845  10373
# 118     Port Alice      Mount Waddington   --     --     --     --     --
# 119  Port Clements           North Coast   --     --     --     --     --
#
#       1961   1966   1971   1976   1981   1986   1991   1996   2001   2006  \
# ...

# %%
BCPop0.loc[110,'RD'] = 'Okanagan-Similkameen'

# %%
BCPop0.loc[111,'RD'] = 'Nanaimo'

# %%
BCPop0.loc[112,'RD'] = 'Central Okanagan'

# %%
BCPop0.loc[113,'RD'] = 'Squamish-Lillooet'

# %%
BCPop0.loc[114,'RD'] = 'Okanagan-Similkameen'

# %%
BCPop0.loc[115,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[116,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[117,'RD'] = 'Alberni-Clayoquot'

# %%
BCPop0.loc[118,'RD'] = 'Mount Waddington'

# %%
BCPop0.loc[119,'RD'] = 'North Coast'

# %%
BCPop0.iloc[120:130]
# Out:
#                Name                    RD   1921   1931   1941   1951   1956  \
# 120  Port Coquitlam     Greater Vancouver   1178   1312   1539   3232   4632
# 121     Port Edward           North Coast   --     --     --     --     --
# 122      Port Hardy      Mount Waddington   --     --     --     --     --
# 123    Port McNeill      Mount Waddington   --     --     --     --     --
# 124      Port Moody     Greater Vancouver   1030   1260   1512   2246   2713
# 125     Pouce Coupe           Peace River   --     --      251    459    585
# 126    Powell River          Powell River   --     --     --     --     9969
# 127   Prince George    Fraser-Fort George   2053   2479   2027   4703  10563
# 128   Prince Rupert           North Coast   6393   6350   6714   8546  10498
# 129       Princeton  Okanagan-Similkameen   --     --     --     --     2245
#
#       1961   1966   1971   1976   1981   1986   1991   1996   2001   2006  \
# ...

# %%
BCPop0.loc[120,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[121,'RD'] = 'North Coast'

# %%
BCPop0.loc[122,'RD'] = 'Mount Waddington'

# %%
BCPop0.loc[123,'RD'] = 'Mount Waddington'

# %%
BCPop0.loc[124,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[125,'RD'] = 'Peace River'

# %%
BCPop0.loc[126,'RD'] = 'Powell River'

# %%
BCPop0.loc[127,'RD'] = 'Fraser-Fort George'

# %%
BCPop0.loc[128,'RD'] = 'North Coast'

# %%
BCPop0.loc[129,'RD'] = 'Okanagan-Similkameen'

# %%
BCPop0.iloc[130:140]
# Out:
#                    Name                 RD   1921   1931   1941   1951   1956  \
# 130      Qualicum Beach            Nanaimo   --     --     --      771    726
# 131     Queen Charlotte        North Coast   --     --     --     --     --
# 132             Quesnel            Cariboo   --      446    653   1587   4384
# 133  Radium Hot Springs      East Kootenay   --     --     --     --     --
# 134          Revelstoke   Columbia-Shuswap   2782   2736   2106   2917   3469
# 135            Richmond  Greater Vancouver   4825   8182  10370  19186  25978
# 136            Rossland  Kootenay Boundary   2097   2848   3657   4604   4344
# 137             Saanich            Capital  10534  12968  18173  28481  38358
# 138               Salmo   Central Kootenay   --     --     --      593    846
# 139     Salmon Arm C/VL   Columbia-Shuswap    627    830    836   1201   1344
#
#       1961   1966   1971   1976   1981    1986    1991    1996    2001  \
# ...

# %%
BCPop0.loc[130,'RD'] = 'Nanaimo'

# %%
BCPop0.loc[131,'RD'] = 'North Coast'

# %%
BCPop0.loc[132,'RD'] = 'Cariboo'

# %%
BCPop0.loc[133,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[134,'RD'] = 'Columbia-Shuswap'

# %%
BCPop0.loc[135,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[136,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.loc[137,'RD'] = 'Capital'

# %%
BCPop0.loc[138,'RD'] = 'Central Kootenay'

# %%
BCPop0.loc[139,'RD'] = 'Columbia-Shuswap'

# %%
BCPop0.iloc[140:150]
# Out:
#                   Name                  RD   1921   1931   1941   1951   1956  \
# 140      Salmon Arm DM    Columbia-Shuswap    967   1671   1786   2389   3100
# 141            Sayward          Strathcona   --     --     --     --     --
# 142            Sechelt      Sunshine Coast   --     --     --     --      439
# 143           Sicamous    Columbia-Shuswap    NaN    NaN    NaN    NaN    NaN
# 144             Sidney             Capital   --     --     --     --     1371
# 145          Silverton    Central Kootenay   --      272    207    339    347
# 146             Slocan    Central Kootenay    286    202    183    374    326
# 147           Smithers     Bulkley-Nechako   --      999    759   1204   1962
# 148              Sooke             Capital   --     --     --     --     --
# 149  South Fort George  Fraser-Fort George   --     --     --     --     --
#
#       1961   1966   1971   1976   1981   1986   1991   1996   2001   2006  \
# ...

# %%
BCPop0.loc[140,'RD'] = 'Columbia-Shuswap'

# %%
BCPop0.loc[141,'RD'] = 'Strathcona'

# %%
BCPop0.loc[142,'RD'] = 'Sunshine Coast'

# %%
BCPop0.loc[143,'RD'] = 'Columbia-Shuswap'

# %%
BCPop0.loc[144,'RD'] = 'Capital'

# %%
BCPop0.loc[145,'RD'] = 'Central Kootenay'

# %%
BCPop0.loc[146,'RD'] = 'Central Kootenay'

# %%
BCPop0.loc[147,'RD'] = 'Bulkley-Nechako'

# %%
BCPop0.loc[148,'RD'] = 'Capital'

# %%
BCPop0.loc[149,'RD'] = 'Fraser-Fort George'

# %%
BCPop0.iloc[150:160]
# Out:
#                    Name                    RD   1921   1931   1941   1951  \
# 150     South Vancouver     Greater Vancouver  32267   --     --     --
# 151        Spallumcheen        North Okanagan    523   1629   1805   1936
# 152            Sparwood         East Kootenay   --     --     --     --
# 153            Squamish     Squamish-Lillooet   --     --     --      589
# 154             Stewart       Kitimat-Stikine   --      610    446    283
# 155               Sumas         Fraser Valley   2299   1812   2473   4015
# 156          Summerland  Okanagan-Similkameen   1892   1791   2054   3567
# 157  Sun Peaks Mountain       Thompson-Nicola   --     --     --     --
# 158              Surrey     Greater Vancouver   5814   8388  14840  33670
# 159             Tadanac     Kootenay Boundary    292    464    510    479
#
#       1956   1961   1966   1971    1976    1981    1986    1991    1996  \
# 150   --     --     --     --      --      --      --      --      --
# ...

# %%
BCPop0.loc[150,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[151,'RD'] = 'North Okanagan'

# %%
BCPop0.loc[152,'RD'] = 'East Kootenay'

# %%
BCPop0.loc[153,'RD'] = 'Squamish-Lillooet'

# %%
BCPop0.loc[154,'RD'] = 'Kitimat-Stikine'

# %%
BCPop0.loc[155,'RD'] = 'Fraser Valley'

# %%
BCPop0.loc[156,'RD'] = 'Okanagan-Similkameen'

# %%
BCPop0.loc[157,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.loc[158,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[159,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.iloc[160:170]
# Out:
#               Name                  RD   1921   1931   1941   1951   1956  \
# 160         Tahsis          Strathcona   --     --     --     --     --
# 161         Taylor         Peace River   --     --     --     --     --
# 162         Telkwa     Bulkley-Nechako   --     --     --     --      580
# 163        Terrace     Kitimat-Stikine   --      352    355    961   1473
# 164         Tofino   Alberni-Clayoquot   --     --      246    302    389
# 165          Trail   Kootenay Boundary   3020   7573   9392  11430  11395
# 166  Tumbler Ridge         Peace River   --     --     --     --     --
# 167       Ucluelet   Alberni-Clayoquot   --     --     --     --      520
# 168      Valemount  Fraser-Fort George   --     --     --     --     --
# 169     Valleyview                 [6]   --     --     --     --     --
#
#       1961   1966   1971   1976   1981   1986   1991   1996   2001   2006  \
# 160   --     --     1351   1663   1739   1445   1053    940    600    366
# ...

# %%
BCPop0.loc[160,'RD'] = 'Strathcona'

# %%
BCPop0.loc[161,'RD'] = 'Peace River'

# %%
BCPop0.loc[162,'RD'] = 'Bulkley-Nechako'

# %%
BCPop0.loc[163,'RD'] = 'Kitimat-Stikine'

# %%
BCPop0.loc[164,'RD'] = 'Alberni-Clayoquot'

# %%
BCPop0.loc[165,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.loc[166,'RD'] = 'Peace River'

# %%
BCPop0.loc[167,'RD'] = 'Alberni-Clayoquot'

# %%
BCPop0.loc[168,'RD'] = 'Fraser-Fort George'

# %%
BCPop0.loc[169,'RD'] = 'Thompson-Nicola'

# %%
BCPop0.iloc[170:180]
# Out:
#                Name                 RD    1921    1931    1941    1951  \
# 170       Vancouver  Greater Vancouver  117217  246593  275353  344833
# 171      Vanderhoof    Bulkley-Nechako    --       305     350     644
# 172          Vernon     North Okanagan    3685    3937    5209    7822
# 173        Victoria            Capital   38727   39082   44068   51331
# 174      View Royal            Capital    --      --      --      --
# 175        Warfield  Kootenay Boundary    --      --      --      --
# 176           Wells            Cariboo    --      --      --      --
# 177    West Kelowna   Central Okanagan    --      --      --      --
# 178  West Vancouver  Greater Vancouver    2434    4786    7669   13990
# 179        Westview       Powell River    --      --      --      3507
#
#        1956    1961    1966    1971    1976    1981    1986    1991    1996  \
# 170  365844  384522  410375  426256  410188  414281  431147  471844  514008
# ...

# %%
BCPop0.loc[170,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[171,'RD'] = 'Bulkley-Nechako'

# %%
BCPop0.loc[172,'RD'] = 'North Okanagan'

# %%
BCPop0.loc[173,'RD'] = 'Capital'

# %%
BCPop0.loc[174,'RD'] = 'Capital'

# %%
BCPop0.loc[175,'RD'] = 'Kootenay Boundary'

# %%
BCPop0.loc[176,'RD'] = 'Cariboo'

# %%
BCPop0.loc[177,'RD'] = 'Central Okanagan'

# %%
BCPop0.loc[178,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[179,'RD'] = 'Powell River'

# %%
BCPop0.iloc[180:190]
# Out:
#                                                   Name                 RD  \
# 180                                           Whistler  Squamish-Lillooet
# 181                                         White Rock  Greater Vancouver
# 182                                      Williams Lake            Cariboo
# 183                                           Zeballos         Strathcona
# 184                                                NaN                NaN
# 185  Note: All figures correspond to municipal boun...                NaN
# 186                                                NaN                NaN
# 187                 [1] Amalgamated with Fort St. John                NaN
# 188                  [2] Amalgamated with Port Alberni                NaN
# 189                           [3] Annexed to Kimberley                NaN
#
#       1921   1931   1941                               1951   1956   1961  \
# 180   --     --     --                                 --     --     --
# ...

# %%
BCPop0.loc[180,'RD'] = 'Squamish-Lillooet'

# %%
BCPop0.loc[181,'RD'] = 'Greater Vancouver'

# %%
BCPop0.loc[182,'RD'] = 'Cariboo'

# %%
BCPop0.loc[183,'RD'] = 'Strathcona'

# %%
BCPop0 = BCPop0.drop(range(184,len(BCPop0)))

# %%
BCPop0.groupby('RD').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[474], line 1
# ----> 1 BCPop0.groupby('RD').sum()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/firstenvironment/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2263, in GroupBy.sum(self, numeric_only, min_count, engine, engine_kwargs)
#    2258 else:
#    2259     # If we are grouping on categoricals we want unobserved categories to
#    2260     # return zero, rather than the default of NaN which the reindexing in
#    2261     # _agg_general() returns. GH #31422
#    2262     with com.temp_setattr(self, "observed", True):
# -> 2263         result = self._agg_general(
#    2264             numeric_only=numeric_only,
#    2265             min_count=min_count,
#    2266             alias="sum",
#    2267             npfunc=np.sum,
#    2268         )
# ...

# %%
BCPop0.drop(columns=['Name'])
# Out:
#                     RD   1921   1931   1941   1951   1956   1961   1966  \
# 0              Cariboo   --     --     --     --     --     --      829
# 1        Fraser Valley   --      510    562    785    830    888    792
# 2          Peace River   --     --     --     --     --     --      989
# 3    Alberni-Clayoquot    540    702   1807   3323   3947   4616   4783
# 4     Mount Waddington   --     --     --      638    695    825    795
# ..                 ...    ...    ...    ...    ...    ...    ...    ...
# 179       Powell River   --     --     --     3507   --     --     --
# 180  Squamish-Lillooet   --     --     --     --     --     --     --
# 181  Greater Vancouver   --     --     --     --     --     6453   7787
# 182            Cariboo   --      402    540    913   1790   2120   3167
# 183         Strathcona   --     --     --     --      154    235    229
#
#       1971   1976   1981   1986   1991    1996    2001    2006    2011
# ...

# %%
print(BCPop0.iloc[0][1921])
type(BCPop0.iloc[0][1921])
# Out:
#  --
# str

# %%
BCPop0.iloc[0,2]
# Out:
# ' --  '

# %%
BCPop0 = BCPop0.replace(BCPop0.iloc[0,2],np.nan)

# %%
BCPop0
# Out:
#                Name                 RD   1921   1931    1941    1951    1956  \
# 0    100 Mile House            Cariboo    NaN    NaN     NaN     NaN     NaN
# 1        Abbotsford      Fraser Valley    NaN  510.0   562.0   785.0   830.0
# 2        Aennofield        Peace River    NaN    NaN     NaN     NaN     NaN
# 3           Alberni  Alberni-Clayoquot  540.0  702.0  1807.0  3323.0  3947.0
# 4         Alert Bay   Mount Waddington    NaN    NaN     NaN   638.0   695.0
# ..              ...                ...    ...    ...     ...     ...     ...
# 179        Westview       Powell River    NaN    NaN     NaN  3507.0     NaN
# 180        Whistler  Squamish-Lillooet    NaN    NaN     NaN     NaN     NaN
# 181      White Rock  Greater Vancouver    NaN    NaN     NaN     NaN     NaN
# 182   Williams Lake            Cariboo    NaN  402.0   540.0   913.0  1790.0
# 183        Zeballos         Strathcona    NaN    NaN     NaN     NaN   154.0
#
# ...

# %%
BCRegPop0 = BCPop0.groupby('RD').sum().drop(columns={'Name'}).transpose()

# %%
BCRegPop1.columns
# Out:
# Index(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Coast', 'Central Kootenay', 'Central Okanagan',
#        'Columbia-Shuswap', 'Comox Valley', 'Cowichan Valley', 'East Kootenay',
#        'Fraser Valley', 'Fraser-Fort George', 'Greater Vancouver',
#        'Kitimat-Stikine', 'Kootenay Boundary', 'Mount Waddington', 'Nanaimo',
#        'North Coast', 'North Okanagan', 'Northern Rockies',
#        'Okanagan-Similkameen', 'Peace River', 'Powell River',
#        'Squamish-Lillooet', 'Stikine', 'Strathcona', 'Sunshine Coast',
#        'Thompson-Nicola'],
#       dtype='object', name='Name')

# %%
BCRegPop0.columns
# Out:
# Index(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Kootenay', 'Central Okanagan', 'Columbia-Shuswap',
#        'Comox Valley', 'Cowichan Valley', 'East Kootenay', 'Fraser Valley',
#        'Fraser-Fort George', 'Greater Vancouver', 'Kitimat-Stikine',
#        'Kootenay Boundary', 'Mount Waddington', 'Nanaimo', 'North Coast',
#        'North Okanagan', 'Northern Rockies', 'Okanagan-Similkameen',
#        'Peace River', 'Powell River', 'Squamish-Lillooet', 'Strathcona',
#        'Sunshine Coast', 'Thompson-Nicola'],
#       dtype='object', name='RD')

# %%
BCRegPop1[['Central Coast','Stikine']]
# Out:
# Name Central Coast Stikine
# 2001        3918.0   614.0
# 2002        3787.0   634.0
# 2003        3538.0   623.0
# 2004        3468.0   629.0
# 2005        3377.0   641.0
# 2006        3273.0   653.0
# 2007        3256.0   625.0
# 2008        3241.0   643.0
# 2009        3242.0   632.0
# 2010        3261.0   639.0
# 2011        3285.0   652.0
# 2011        3285.0   652.0
# 2012        3306.0   665.0
# 2013        3373.0   691.0
# 2014        3360.0   719.0
# 2015        3359.0   741.0
# 2016        3464.0   767.0
# 2017        3485.0   731.0
# 2018        3548.0   736.0
# 2019        3553.0   712.0
# 2020        3578.0   702.0
# 2021        3621.0   710.0
# 2022        3688.0   722.0

# %%
pd.concat([BCRegPop0,BCRegPop1])
# Out:
#      Alberni-Clayoquot Bulkley-Nechako   Capital  Cariboo Central Kootenay  \
# 1921            1596.0             0.0   56878.0      0.0           6466.0
# 1931            3058.0          1506.0   61216.0    848.0           7990.0
# 1941            6637.0          1327.0   75218.0   1193.0           8233.0
# 1951           11470.0          2649.0  103994.0   2500.0          13481.0
# 1956           15229.0          5258.0  122031.0   6174.0          15004.0
# 1961           17398.0          7344.0  137310.0   6793.0          16587.0
# 1966           20069.0          8512.0  157008.0   9721.0          23107.0
# 1971           21542.0         12495.0  171754.0  11444.0          22548.0
# 1976           21377.0         15320.0  187487.0  15420.0          23575.0
# 1981           22190.0         18688.0  199902.0  18527.0          25026.0
# 1986           20693.0         18520.0  225206.0  20330.0          23001.0
# ...

# %%
pd.concat([BCRegPop0,BCRegPop1]).iloc[:,20:30]
# Out:
#      Okanagan-Similkameen Peace River Powell River Squamish-Lillooet  \
# 1921               5871.0         0.0          0.0               0.0
# 1931               6431.0         0.0          0.0               0.0
# 1941               7831.0       769.0          0.0               0.0
# 1951              16014.0      4932.0       4857.0            1058.0
# 1956              20039.0     10024.0       9969.0            2375.0
# 1961              23688.0     15672.0      10748.0            3042.0
# 1966              25320.0     25763.0      12578.0            5791.0
# 1971              29803.0     24350.0      13726.0            7792.0
# 1976              35643.0     23717.0      13694.0           11371.0
# 1981              39166.0     30969.0      13423.0           13644.0
# 1986              40011.0     33742.0      12440.0           14264.0
# 1991              47386.0     35268.0      12991.0           18452.0
# 1996              53870.0     35948.0      13131.0           24009.0
# ...

# %% [markdown]
# Need to account for the different numbers that are coming from municipal counts vs regional counts.  Maybe look for a common ratio.

# %%
BCRegPop1.loc[[2001,2006,2011]]
# Out:
# RD    Alberni-Clayoquot  Bulkley-Nechako   Capital  Cariboo  Central Kootenay  \
# 2001            20768.0          20242.0  303539.0  23171.0           26041.0
# 2006            20690.0          18678.0  321269.0  22191.0           25957.0
# 2011            21246.0          19571.0  335256.0  22970.0           28081.0
#
# RD    Central Okanagan  Columbia-Shuswap  Comox Valley  Cowichan Valley  \
# 2001          110209.0           29450.0       32094.0          40261.0
# 2006          121196.0           29729.0       36838.0          43029.0
# 2011          165112.0           30745.0       41124.0          44634.0
#
# RD    East Kootenay  ...  North Coast  North Okanagan  Northern Rockies  \
# 2001        39413.0  ...      16744.0         56426.0            4188.0
# 2006        39141.0  ...      15720.0         59078.0            4514.0
# 2011        41056.0  ...      15258.0         62997.0            4987.0
#
# ...

# %%
BCRegPop1.loc[[2001,2006,2011]]
# Out:
# Name Alberni-Clayoquot Bulkley-Nechako   Capital  Cariboo Central Coast  \
# 2001           31608.0         42493.0  340002.0  68226.0        3918.0
# 2006           31479.0         39378.0  355050.0  63872.0        3273.0
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
#
# Name Central Kootenay Central Okanagan Columbia-Shuswap Comox Valley  \
# 2001          59366.0         154196.0          50198.0      57557.0
# 2006          57204.0         167112.0          51346.0      60956.0
# 2011          59348.0         183607.0          51275.0      64486.0
# 2011          59348.0         183607.0          51275.0      64486.0
#
# Name Cowichan Valley  ... North Okanagan Northern Rockies  \
# 2001         75040.0  ...        76334.0           5985.0
# 2006         78864.0  ...        79250.0           6383.0
# 2011         81567.0  ...        82469.0           6067.0
# ...

# %%
(BCRegPop1.loc[[2001,2006,2011]] / BCRegPop0.loc[[2001,2006,2011]]).mean().mean()
# Out:
# 1.5471102360954614

# %% [markdown]
# So perhaps it's reasonable to do a x1.5 multiplier to all the earlier municipal sums to get the regional populations at those times.

# %%
BCRegPop0Adj = (BCRegPop0.drop([2001,2006,2011]))*1.5

# %%
BCRegPopAdj = pd.concat([BCRegPop0Adj,BCRegPop1])

# %%
BCRegPopAdj.columns
# Out:
# Index(['Alberni-Clayoquot', 'Bulkley-Nechako', 'Capital', 'Cariboo',
#        'Central Kootenay', 'Central Okanagan', 'Columbia-Shuswap',
#        'Comox Valley', 'Cowichan Valley', 'East Kootenay', 'Fraser Valley',
#        'Fraser-Fort George', 'Greater Vancouver', 'Kitimat-Stikine',
#        'Kootenay Boundary', 'Mount Waddington', 'Nanaimo', 'North Coast',
#        'North Okanagan', 'Northern Rockies', 'Okanagan-Similkameen',
#        'Peace River', 'Powell River', 'Squamish-Lillooet', 'Strathcona',
#        'Sunshine Coast', 'Thompson-Nicola', 'Central Coast', 'Stikine'],
#       dtype='object')

# %%
BCRegPopAdj
# Out:
#      Alberni-Clayoquot Bulkley-Nechako   Capital  Cariboo Central Kootenay  \
# 1921            2394.0             0.0   85317.0      0.0           9699.0
# 1931            4587.0          2259.0   91824.0   1272.0          11985.0
# 1941            9955.5          1990.5  112827.0   1789.5          12349.5
# 1951           17205.0          3973.5  155991.0   3750.0          20221.5
# 1956           22843.5          7887.0  183046.5   9261.0          22506.0
# 1961           26097.0         11016.0  205965.0  10189.5          24880.5
# 1966           30103.5         12768.0  235512.0  14581.5          34660.5
# 1971           32313.0         18742.5  257631.0  17166.0          33822.0
# 1976           32065.5         22980.0  281230.5  23130.0          35362.5
# 1981           33285.0         28032.0  299853.0  27790.5          37539.0
# 1986           31039.5         27780.0  337809.0  30495.0          34501.5
# ...

# %%
(BCRegPop1.loc[[2001,2006,2011]] / BCRegPop0.loc[[2001,2006,2011]]).mean()
# Out:
# Alberni-Clayoquot       1.505065
# Bulkley-Nechako         2.071676
# Capital                 1.104582
# Cariboo                 2.835311
# Central Coast                NaN
# Central Kootenay        2.177607
# Central Okanagan        1.250503
# Columbia-Shuswap        1.691788
# Comox Valley            1.646067
# Cowichan Valley         1.837894
# East Kootenay           1.438268
# Fraser Valley            1.09947
# Fraser-Fort George      1.229825
# Greater Vancouver       1.041827
# Kitimat-Stikine         1.798085
# Kootenay Boundary       1.508668
# Mount Waddington        1.511442
# Nanaimo                  1.40476
# North Coast             1.284291
# North Okanagan          1.328113
# Northern Rockies        1.319064
# Okanagan-Similkameen    1.439396
# Peace River             1.631428
# Powell River            1.546976
# Squamish-Lillooet       1.252262
# Stikine                      NaN
# Strathcona              1.345247
# Sunshine Coast          2.186669
# ...

# %%
BCRegPop0.loc[[2001,2006,2011]] * ((BCRegPop1.loc[[2001,2006,2011]] / BCRegPop0.loc[[2001,2006,2011]]).mean())
# Out:
#      Alberni-Clayoquot Bulkley-Nechako        Capital       Cariboo  \
# 2001       31257.18576    41934.863581  335283.667307  65696.984323
# 2006      31139.790706    38694.762472  354867.903341  62918.379833
# 2011      31976.606735    40544.769051  370317.689545  65127.086871
#
#      Central Coast Central Kootenay Central Okanagan Columbia-Shuswap  \
# 2001           NaN     56707.053122    137816.647135     49823.163648
# 2006           NaN     56524.134169    151555.919809     50295.172566
# 2011           NaN     61149.370559    206472.994418     52014.029417
#
#       Comox Valley Cowichan Valley  ... North Okanagan Northern Rockies  \
# 2001  52828.858873    73995.446527  ...   74940.092092      5524.238373
# 2006  60637.798441    79082.736857  ...   78462.247202      5954.253108
# 2011  67692.839543    82032.556575  ...   83667.121213      6578.170192
#
#      Okanagan-Similkameen   Peace River  Powell River Squamish-Lillooet  \
# ...

# %%
BCRegPop1.loc[[2001,2006,2011]]
# Out:
# Name Alberni-Clayoquot Bulkley-Nechako   Capital  Cariboo Central Coast  \
# 2001           31608.0         42493.0  340002.0  68226.0        3918.0
# 2006           31479.0         39378.0  355050.0  63872.0        3273.0
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
# 2011           31623.0         39917.0  367617.0  63380.0        3285.0
#
# Name Central Kootenay Central Okanagan Columbia-Shuswap Comox Valley  \
# 2001          59366.0         154196.0          50198.0      57557.0
# 2006          57204.0         167112.0          51346.0      60956.0
# 2011          59348.0         183607.0          51275.0      64486.0
# 2011          59348.0         183607.0          51275.0      64486.0
#
# Name Cowichan Valley  ... North Okanagan Northern Rockies  \
# 2001         75040.0  ...        76334.0           5985.0
# 2006         78864.0  ...        79250.0           6383.0
# 2011         81567.0  ...        82469.0           6067.0
# ...

# %%
BCRegPopAdj2 = BCRegPop0 * ((BCRegPop1.loc[[2001,2006,2011]] / BCRegPop0.loc[[2001,2006,2011]]).mean())

# %%
BCRegPopAdj2 = pd.concat([BCRegPopAdj2.drop([2001,2006,2011]),BCRegPop1])

# %%
BCRegPopAdj2
# Out:
#      Alberni-Clayoquot Bulkley-Nechako        Capital       Cariboo  \
# 1921        2402.08342             0.0   62826.405928           0.0
# 1931       4602.488158     3119.943906   67618.081953   2404.343477
# 1941       9989.115076      2749.11392   83084.436885    3382.52567
# 1951      17263.093253     5487.869461  114869.883929    7088.27676
# 1956      22920.631835    10892.871886  134793.226588  17505.208287
# 1961      26185.117385    15214.387814   151670.13253  19260.265612
# 1966      30205.145465    17634.105266  173428.185626  27562.055354
# 1971      32422.105915    25885.590378  189716.349447  32447.295697
# 1976      32173.770223    31738.074798  207094.735544  43720.491056
# 1981      33397.387906    38715.479231  220808.119095  52529.801413
# 1986        31144.3059     38367.43768  248758.457989  57641.866613
# 1991      31758.372339    40364.533248  284814.218429  57925.397683
# 1996      32051.859975    43053.568567  318711.625953  58946.109536
# ...

# %%
BCPop1990 = BCRegPopAdj2.drop([1921,1931,1941,1951,1956,1961,1966,1971,1976,1981,1986])

# %%
BCPop1990
# Out:
#      Alberni-Clayoquot Bulkley-Nechako        Capital       Cariboo  \
# 1991      31758.372339    40364.533248  284814.218429  57925.397683
# 1996      32051.859975    43053.568567  318711.625953  58946.109536
# 2001           31608.0         42493.0       340002.0       68226.0
# 2002           31251.0         41456.0       342012.0       66701.0
# 2003           31279.0         40837.0       344180.0       65487.0
# 2004           31281.0         40542.0       346761.0       64573.0
# 2005           31522.0         39796.0       352078.0       64005.0
# 2006           31479.0         39378.0       355050.0       63872.0
# 2007           31430.0         39531.0       357049.0       64294.0
# 2008           31562.0         39739.0       359585.0       64679.0
# 2009           31699.0         39721.0       363445.0       64169.0
# 2010           31749.0         39979.0       366716.0       63796.0
# 2011           31623.0         39917.0       367617.0       63380.0
# ...

# %%
BCPop1990.to_csv('BCPop1990.csv')
